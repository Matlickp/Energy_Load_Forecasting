# %%
import pandas as pd
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.energyDB
coll = db.forecastSDGE

# %%
forecast_df = pd.read_csv('FCWeatherdata_SDGE.csv') 
forecast_df.head()
# Out:
#    CODE STATUS         FCDATE LOCATION     FCDATETIME  FCYYYY  FCMM  FCDD  \
# 0  KNKX      O  2019-01-01 00      NKX  1/1/2019 0:00    2019     1     1
# 1  KNKX      O  2019-01-01 01      NKX  1/1/2019 1:00    2019     1     1
# 2  KNKX      O  2019-01-01 02      NKX  1/1/2019 2:00    2019     1     1
# 3  KNKX      O  2019-01-01 03      NKX  1/1/2019 3:00    2019     1     1
# 4  KNKX      O  2019-01-01 04      NKX  1/1/2019 4:00    2019     1     1
#
#    FCHH  FCDOWNUM FCDOWTEXT  TMP  DPT  HUM  CC    CREATEDBY CREATEDDATE
# 0     0         3       TUE   47   35   63  30  SESImporter     48:35.3
# 1     1         3       TUE   47   35   63  30  SESImporter     48:35.3
# 2     2         3       TUE   47   33   58  30  SESImporter     48:35.3
# 3     3         3       TUE   45   33   63  30  SESImporter     48:35.3
# 4     4         3       TUE   44   33   65   0  SESImporter     48:35.3

# %%
forecast_df['CODE'].unique()
# Out:
# array(['KNKX'], dtype=object)

# %%
forecast_dict = forecast_df.to_dict(orient='records')
forecast_dict
# Out:
# [{'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 0,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 47,
#   'DPT': 35,
#   'HUM': 63,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 1,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 47,
#   'DPT': 35,
#   'HUM': 63,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 2,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 47,
#   'DPT': 33,
#   'HUM': 58,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 3,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 45,
#   'DPT': 33,
#   'HUM': 63,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 4,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 44,
#   'DPT': 33,
#   'HUM': 65,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 5,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 43,
#   'DPT': 31,
#   'HUM': 63,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 6,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 44,
#   'DPT': 28,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 7,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 43,
#   'DPT': 27,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 8,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 47,
#   'DPT': 28,
#   'HUM': 48,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 9,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 54,
#   'DPT': 27,
#   'HUM': 35,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 10,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 54,
#   'DPT': 26,
#   'HUM': 34,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 11,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 54,
#   'DPT': 23,
#   'HUM': 30,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 12,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 57,
#   'DPT': 21,
#   'HUM': 25,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 13,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 58,
#   'DPT': 17,
#   'HUM': 20,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 14,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 61,
#   'DPT': 16,
#   'HUM': 17,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 15,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 57,
#   'DPT': 18,
#   'HUM': 22,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 16,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 57,
#   'DPT': 21,
#   'HUM': 25,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 17,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 52,
#   'DPT': 18,
#   'HUM': 26,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 18,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 50,
#   'DPT': 17,
#   'HUM': 27,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 19,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 49,
#   'DPT': 15,
#   'HUM': 26,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 20,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 46,
#   'DPT': 14,
#   'HUM': 27,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 21,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 46,
#   'DPT': 15,
#   'HUM': 29,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 22,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 46,
#   'DPT': 18,
#   'HUM': 33,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-01 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/1/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 1,
#   'FCHH': 23,
#   'FCDOWNUM': 3,
#   'FCDOWTEXT': 'TUE',
#   'TMP': 45,
#   'DPT': 18,
#   'HUM': 34,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '48:35.3'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 0,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 42,
#   'DPT': 18,
#   'HUM': 38,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 1,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 43,
#   'DPT': 16,
#   'HUM': 34,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 2,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 43,
#   'DPT': 16,
#   'HUM': 34,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 3,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 42,
#   'DPT': 17,
#   'HUM': 36,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 4,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 42,
#   'DPT': 19,
#   'HUM': 40,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 5,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 41,
#   'DPT': 19,
#   'HUM': 41,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 6,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 41,
#   'DPT': 19,
#   'HUM': 41,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 7,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 41,
#   'DPT': 19,
#   'HUM': 41,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 8,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 46,
#   'DPT': 20,
#   'HUM': 36,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 9,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 52,
#   'DPT': 22,
#   'HUM': 31,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 10,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 53,
#   'DPT': 18,
#   'HUM': 25,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 11,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 55,
#   'DPT': 13,
#   'HUM': 19,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 12,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 58,
#   'DPT': 16,
#   'HUM': 19,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 13,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 59,
#   'DPT': 17,
#   'HUM': 19,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 14,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 62,
#   'DPT': 21,
#   'HUM': 21,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 15,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 58,
#   'DPT': 28,
#   'HUM': 32,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 16,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 57,
#   'DPT': 32,
#   'HUM': 39,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 17,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 53,
#   'DPT': 32,
#   'HUM': 45,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 18,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 50,
#   'DPT': 33,
#   'HUM': 52,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 19,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 50,
#   'DPT': 30,
#   'HUM': 46,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 20,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 48,
#   'DPT': 30,
#   'HUM': 50,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 21,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 48,
#   'DPT': 31,
#   'HUM': 52,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 22,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 47,
#   'DPT': 32,
#   'HUM': 56,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-02 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/2/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 2,
#   'FCHH': 23,
#   'FCDOWNUM': 4,
#   'FCDOWTEXT': 'WED',
#   'TMP': 45,
#   'DPT': 31,
#   'HUM': 58,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '43:07.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 0,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 45,
#   'DPT': 29,
#   'HUM': 54,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 1,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 43,
#   'DPT': 27,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 2,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 43,
#   'DPT': 27,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 3,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 42,
#   'DPT': 26,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 4,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 42,
#   'DPT': 26,
#   'HUM': 53,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 5,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 40,
#   'DPT': 25,
#   'HUM': 55,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 6,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 39,
#   'DPT': 24,
#   'HUM': 55,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 7,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 41,
#   'DPT': 26,
#   'HUM': 55,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 8,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 47,
#   'DPT': 27,
#   'HUM': 46,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 9,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 54,
#   'DPT': 25,
#   'HUM': 33,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 10,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 54,
#   'DPT': 23,
#   'HUM': 30,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 11,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 57,
#   'DPT': 21,
#   'HUM': 25,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 12,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 59,
#   'DPT': 24,
#   'HUM': 26,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 13,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 60,
#   'DPT': 28,
#   'HUM': 30,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 14,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 64,
#   'DPT': 28,
#   'HUM': 26,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 15,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 61,
#   'DPT': 29,
#   'HUM': 30,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 16,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 60,
#   'DPT': 30,
#   'HUM': 32,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 17,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 56,
#   'DPT': 29,
#   'HUM': 36,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 18,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 53,
#   'DPT': 32,
#   'HUM': 45,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 19,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 51,
#   'DPT': 34,
#   'HUM': 52,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 20,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 49,
#   'DPT': 33,
#   'HUM': 54,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 21,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 50,
#   'DPT': 34,
#   'HUM': 54,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 22,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 50,
#   'DPT': 37,
#   'HUM': 61,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-03 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/3/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 3,
#   'FCHH': 23,
#   'FCDOWNUM': 5,
#   'FCDOWTEXT': 'THU',
#   'TMP': 47,
#   'DPT': 36,
#   'HUM': 66,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:33.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 0,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 46,
#   'DPT': 36,
#   'HUM': 68,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 1,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 45,
#   'DPT': 34,
#   'HUM': 65,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 2,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 45,
#   'DPT': 34,
#   'HUM': 65,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 3,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 44,
#   'DPT': 33,
#   'HUM': 65,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 4,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 44,
#   'DPT': 30,
#   'HUM': 58,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 5,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 42,
#   'DPT': 32,
#   'HUM': 68,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 6,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 41,
#   'DPT': 31,
#   'HUM': 68,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 7,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 42,
#   'DPT': 29,
#   'HUM': 60,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 8,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 48,
#   'DPT': 32,
#   'HUM': 54,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 9,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 58,
#   'DPT': 29,
#   'HUM': 33,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 10,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 62,
#   'DPT': 22,
#   'HUM': 21,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 11,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 65,
#   'DPT': 23,
#   'HUM': 20,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 12,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 66,
#   'DPT': 23,
#   'HUM': 19,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 13,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 68,
#   'DPT': 25,
#   'HUM': 20,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 14,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 65,
#   'DPT': 33,
#   'HUM': 31,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 15,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 65,
#   'DPT': 32,
#   'HUM': 29,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 16,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 64,
#   'DPT': 31,
#   'HUM': 29,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 17,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 58,
#   'DPT': 37,
#   'HUM': 46,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 18,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 54,
#   'DPT': 38,
#   'HUM': 55,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 19,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 48,
#   'DPT': 37,
#   'HUM': 66,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 20,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 49,
#   'DPT': 38,
#   'HUM': 66,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 21,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 47,
#   'DPT': 38,
#   'HUM': 71,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 22,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 48,
#   'DPT': 38,
#   'HUM': 68,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-04 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/4/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 4,
#   'FCHH': 23,
#   'FCDOWNUM': 6,
#   'FCDOWTEXT': 'FRI',
#   'TMP': 47,
#   'DPT': 37,
#   'HUM': 69,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:32.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 0,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 48,
#   'DPT': 37,
#   'HUM': 66,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 1,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 50,
#   'DPT': 37,
#   'HUM': 61,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 2,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 51,
#   'DPT': 36,
#   'HUM': 56,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 3,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 51,
#   'DPT': 36,
#   'HUM': 56,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 4,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 51,
#   'DPT': 37,
#   'HUM': 59,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 5,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 51,
#   'DPT': 36,
#   'HUM': 56,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 6,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 51,
#   'DPT': 36,
#   'HUM': 56,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 7,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 50,
#   'DPT': 37,
#   'HUM': 61,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 8,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 52,
#   'DPT': 37,
#   'HUM': 57,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 9,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 56,
#   'DPT': 35,
#   'HUM': 46,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 10,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 57,
#   'DPT': 43,
#   'HUM': 60,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 11,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 59,
#   'DPT': 45,
#   'HUM': 60,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 12,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 60,
#   'DPT': 47,
#   'HUM': 62,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 13,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 62,
#   'DPT': 46,
#   'HUM': 56,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 14,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 60,
#   'DPT': 42,
#   'HUM': 52,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 15,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 60,
#   'DPT': 39,
#   'HUM': 46,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 16,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 59,
#   'DPT': 42,
#   'HUM': 54,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 17,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 56,
#   'DPT': 46,
#   'HUM': 70,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 18,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 55,
#   'DPT': 46,
#   'HUM': 72,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 19,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 54,
#   'DPT': 47,
#   'HUM': 77,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 20,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 54,
#   'DPT': 47,
#   'HUM': 77,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 21,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 54,
#   'DPT': 47,
#   'HUM': 77,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 22,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 55,
#   'DPT': 48,
#   'HUM': 77,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-05 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/5/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 5,
#   'FCHH': 23,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 54,
#   'DPT': 49,
#   'HUM': 83,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:47.5'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 0,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 55,
#   'DPT': 50,
#   'HUM': 83,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 1,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 54,
#   'DPT': 49,
#   'HUM': 83,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 2,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 54,
#   'DPT': 49,
#   'HUM': 83,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 3,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 53,
#   'DPT': 48,
#   'HUM': 83,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 4,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 54,
#   'DPT': 48,
#   'HUM': 80,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 5,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 55,
#   'DPT': 49,
#   'HUM': 80,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 6,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 54,
#   'DPT': 50,
#   'HUM': 87,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 7,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 54,
#   'DPT': 50,
#   'HUM': 87,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 8,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 56,
#   'DPT': 51,
#   'HUM': 84,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 9,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 58,
#   'DPT': 51,
#   'HUM': 78,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 10,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 50,
#   'HUM': 70,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 11,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 61,
#   'DPT': 49,
#   'HUM': 65,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 12,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 63,
#   'DPT': 49,
#   'HUM': 60,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 13,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 61,
#   'DPT': 49,
#   'HUM': 65,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 14,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 62,
#   'DPT': 45,
#   'HUM': 54,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 15,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 61,
#   'DPT': 46,
#   'HUM': 58,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 16,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 44,
#   'HUM': 56,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 17,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 57,
#   'DPT': 45,
#   'HUM': 64,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 18,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 52,
#   'DPT': 44,
#   'HUM': 75,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 19,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 50,
#   'DPT': 43,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 20,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 49,
#   'DPT': 42,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 21,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 49,
#   'DPT': 42,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 22,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 50,
#   'DPT': 44,
#   'HUM': 80,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-06 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/6/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 6,
#   'FCHH': 23,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 51,
#   'DPT': 43,
#   'HUM': 74,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-07 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/7/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 7,
#   'FCHH': 0,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 50,
#   'DPT': 43,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-07 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/7/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 7,
#   'FCHH': 1,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 50,
#   'DPT': 42,
#   'HUM': 74,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-07 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/7/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 7,
#   'FCHH': 2,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 49,
#   'DPT': 42,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '38:52.2'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-01-07 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '1/7/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 1,
#   'FCDD': 7,
#   'FCHH': 3,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 49,
#   'DPT': 42,
#   'HUM': 77,
#   'CC': 30,
# ...
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 15,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 62,
#   'DPT': 43,
#   'HUM': 50,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 16,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 60,
#   'DPT': 45,
#   'HUM': 58,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 17,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 59,
#   'DPT': 45,
#   'HUM': 60,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 18,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 55,
#   'DPT': 45,
#   'HUM': 69,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 19,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 52,
#   'DPT': 44,
#   'HUM': 75,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 20,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 49,
#   'DPT': 43,
#   'HUM': 80,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 21,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 48,
#   'DPT': 42,
#   'HUM': 80,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 22,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 48,
#   'DPT': 41,
#   'HUM': 77,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-09 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/9/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 9,
#   'FCHH': 23,
#   'FCDOWNUM': 7,
#   'FCDOWTEXT': 'SAT',
#   'TMP': 47,
#   'DPT': 42,
#   'HUM': 83,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '52:59.1'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 0,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 48,
#   'DPT': 42,
#   'HUM': 80,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 1,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 47,
#   'DPT': 41,
#   'HUM': 80,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 2,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 47,
#   'DPT': 41,
#   'HUM': 80,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 3,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 46,
#   'DPT': 40,
#   'HUM': 79,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 4,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 46,
#   'DPT': 40,
#   'HUM': 79,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 5,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 45,
#   'DPT': 39,
#   'HUM': 80,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 6,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 47,
#   'DPT': 40,
#   'HUM': 77,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 7,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 48,
#   'DPT': 41,
#   'HUM': 77,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 8,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 50,
#   'DPT': 42,
#   'HUM': 74,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 9,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 56,
#   'DPT': 43,
#   'HUM': 62,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 10,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 61,
#   'DPT': 44,
#   'HUM': 54,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 11,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 41,
#   'HUM': 50,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 12,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 44,
#   'HUM': 56,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 13,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 58,
#   'DPT': 47,
#   'HUM': 65,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 14,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 43,
#   'HUM': 53,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 15,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 40,
#   'HUM': 47,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 16',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 16:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 16,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 60,
#   'DPT': 41,
#   'HUM': 50,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 17',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 17:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 17,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 58,
#   'DPT': 42,
#   'HUM': 56,
#   'CC': 70,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 18',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 18:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 18,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 57,
#   'DPT': 44,
#   'HUM': 62,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 19',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 19:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 19,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 55,
#   'DPT': 45,
#   'HUM': 69,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 20',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 20:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 20,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 53,
#   'DPT': 47,
#   'HUM': 80,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 21',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 21:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 21,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 51,
#   'DPT': 46,
#   'HUM': 83,
#   'CC': 100,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 22',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 22:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 22,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 52,
#   'DPT': 40,
#   'HUM': 64,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-10 23',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/10/2019 23:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 10,
#   'FCHH': 23,
#   'FCDOWNUM': 1,
#   'FCDOWTEXT': 'SUN',
#   'TMP': 50,
#   'DPT': 36,
#   'HUM': 59,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 00',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 0:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 0,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 45,
#   'DPT': 37,
#   'HUM': 74,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 01',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 1:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 1,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 45,
#   'DPT': 37,
#   'HUM': 74,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 02',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 2:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 2,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 46,
#   'DPT': 38,
#   'HUM': 73,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 03',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 3:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 3,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 46,
#   'DPT': 38,
#   'HUM': 73,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 04',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 4:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 4,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 45,
#   'DPT': 38,
#   'HUM': 77,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 05',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 5:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 5,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 44,
#   'DPT': 37,
#   'HUM': 76,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 06',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 6:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 6,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 44,
#   'DPT': 37,
#   'HUM': 76,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 07',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 7:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 7,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 43,
#   'DPT': 37,
#   'HUM': 80,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 08',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 8:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 8,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 49,
#   'DPT': 38,
#   'HUM': 66,
#   'CC': 0,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 09',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 9:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 9,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 54,
#   'DPT': 36,
#   'HUM': 51,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 10',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 10:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 10,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 57,
#   'DPT': 34,
#   'HUM': 42,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 11',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 11:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 11,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 59,
#   'DPT': 31,
#   'HUM': 35,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 12',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 12:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 12,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 61,
#   'DPT': 28,
#   'HUM': 29,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 13',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 13:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 13,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 63,
#   'DPT': 39,
#   'HUM': 41,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 14',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 14:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 14,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 62,
#   'DPT': 38,
#   'HUM': 41,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  {'CODE': 'KNKX',
#   'STATUS': 'O',
#   'FCDATE': '2019-02-11 15',
#   'LOCATION': 'NKX',
#   'FCDATETIME': '2/11/2019 15:00',
#   'FCYYYY': 2019,
#   'FCMM': 2,
#   'FCDD': 11,
#   'FCHH': 15,
#   'FCDOWNUM': 2,
#   'FCDOWTEXT': 'MON',
#   'TMP': 60,
#   'DPT': 36,
#   'HUM': 41,
#   'CC': 30,
#   'CREATEDBY': 'SESImporter',
#   'CREATEDDATE': '37:37.8'},
#  ...]

# %%
for record in forecast_dict:
    coll.insert_one(record)

# %%
datelist = forecast_df['FCDATE'].tolist()
datelist
# Out:
# ['2019-01-01 00',
#  '2019-01-01 01',
#  '2019-01-01 02',
#  '2019-01-01 03',
#  '2019-01-01 04',
#  '2019-01-01 05',
#  '2019-01-01 06',
#  '2019-01-01 07',
#  '2019-01-01 08',
#  '2019-01-01 09',
#  '2019-01-01 10',
#  '2019-01-01 11',
#  '2019-01-01 12',
#  '2019-01-01 13',
#  '2019-01-01 14',
#  '2019-01-01 15',
#  '2019-01-01 16',
#  '2019-01-01 17',
#  '2019-01-01 18',
#  '2019-01-01 19',
#  '2019-01-01 20',
#  '2019-01-01 21',
#  '2019-01-01 22',
#  '2019-01-01 23',
#  '2019-01-02 00',
#  '2019-01-02 01',
#  '2019-01-02 02',
#  '2019-01-02 03',
#  '2019-01-02 04',
#  '2019-01-02 05',
#  '2019-01-02 06',
#  '2019-01-02 07',
#  '2019-01-02 08',
#  '2019-01-02 09',
#  '2019-01-02 10',
#  '2019-01-02 11',
#  '2019-01-02 12',
#  '2019-01-02 13',
#  '2019-01-02 14',
#  '2019-01-02 15',
#  '2019-01-02 16',
#  '2019-01-02 17',
#  '2019-01-02 18',
#  '2019-01-02 19',
#  '2019-01-02 20',
#  '2019-01-02 21',
#  '2019-01-02 22',
#  '2019-01-02 23',
#  '2019-01-03 00',
#  '2019-01-03 01',
#  '2019-01-03 02',
#  '2019-01-03 03',
#  '2019-01-03 04',
#  '2019-01-03 05',
#  '2019-01-03 06',
#  '2019-01-03 07',
#  '2019-01-03 08',
#  '2019-01-03 09',
#  '2019-01-03 10',
#  '2019-01-03 11',
#  '2019-01-03 12',
#  '2019-01-03 13',
#  '2019-01-03 14',
#  '2019-01-03 15',
#  '2019-01-03 16',
#  '2019-01-03 17',
#  '2019-01-03 18',
#  '2019-01-03 19',
#  '2019-01-03 20',
#  '2019-01-03 21',
#  '2019-01-03 22',
#  '2019-01-03 23',
#  '2019-01-04 00',
#  '2019-01-04 01',
#  '2019-01-04 02',
#  '2019-01-04 03',
#  '2019-01-04 04',
#  '2019-01-04 05',
#  '2019-01-04 06',
#  '2019-01-04 07',
#  '2019-01-04 08',
#  '2019-01-04 09',
#  '2019-01-04 10',
#  '2019-01-04 11',
#  '2019-01-04 12',
#  '2019-01-04 13',
#  '2019-01-04 14',
#  '2019-01-04 15',
#  '2019-01-04 16',
#  '2019-01-04 17',
#  '2019-01-04 18',
#  '2019-01-04 19',
#  '2019-01-04 20',
#  '2019-01-04 21',
#  '2019-01-04 22',
#  '2019-01-04 23',
#  '2019-01-05 00',
#  '2019-01-05 01',
#  '2019-01-05 02',
#  '2019-01-05 03',
#  '2019-01-05 04',
#  '2019-01-05 05',
#  '2019-01-05 06',
#  '2019-01-05 07',
#  '2019-01-05 08',
#  '2019-01-05 09',
#  '2019-01-05 10',
#  '2019-01-05 11',
#  '2019-01-05 12',
#  '2019-01-05 13',
#  '2019-01-05 14',
#  '2019-01-05 15',
#  '2019-01-05 16',
#  '2019-01-05 17',
#  '2019-01-05 18',
#  '2019-01-05 19',
#  '2019-01-05 20',
#  '2019-01-05 21',
#  '2019-01-05 22',
#  '2019-01-05 23',
#  '2019-01-06 00',
#  '2019-01-06 01',
#  '2019-01-06 02',
#  '2019-01-06 03',
#  '2019-01-06 04',
#  '2019-01-06 05',
#  '2019-01-06 06',
#  '2019-01-06 07',
#  '2019-01-06 08',
#  '2019-01-06 09',
#  '2019-01-06 10',
#  '2019-01-06 11',
#  '2019-01-06 12',
#  '2019-01-06 13',
#  '2019-01-06 14',
#  '2019-01-06 15',
#  '2019-01-06 16',
#  '2019-01-06 17',
#  '2019-01-06 18',
#  '2019-01-06 19',
#  '2019-01-06 20',
#  '2019-01-06 21',
#  '2019-01-06 22',
#  '2019-01-06 23',
#  '2019-01-07 00',
#  '2019-01-07 01',
#  '2019-01-07 02',
#  '2019-01-07 03',
#  '2019-01-07 04',
#  '2019-01-07 05',
#  '2019-01-07 06',
#  '2019-01-07 07',
#  '2019-01-07 08',
#  '2019-01-07 09',
#  '2019-01-07 10',
#  '2019-01-07 11',
#  '2019-01-07 12',
#  '2019-01-07 13',
#  '2019-01-07 14',
#  '2019-01-07 15',
#  '2019-01-07 16',
#  '2019-01-07 17',
#  '2019-01-07 18',
#  '2019-01-07 19',
#  '2019-01-07 20',
#  '2019-01-07 21',
#  '2019-01-07 22',
#  '2019-01-07 23',
#  '2019-01-08 00',
#  '2019-01-08 01',
#  '2019-01-08 02',
#  '2019-01-08 03',
#  '2019-01-08 04',
#  '2019-01-08 05',
#  '2019-01-08 06',
#  '2019-01-08 07',
#  '2019-01-08 08',
#  '2019-01-08 09',
#  '2019-01-08 10',
#  '2019-01-08 11',
#  '2019-01-08 12',
#  '2019-01-08 13',
#  '2019-01-08 14',
#  '2019-01-08 15',
#  '2019-01-08 16',
#  '2019-01-08 17',
#  '2019-01-08 18',
#  '2019-01-08 19',
#  '2019-01-08 20',
#  '2019-01-08 21',
#  '2019-01-08 22',
#  '2019-01-08 23',
#  '2019-01-09 00',
#  '2019-01-09 01',
#  '2019-01-09 02',
#  '2019-01-09 03',
#  '2019-01-09 04',
#  '2019-01-09 05',
#  '2019-01-09 06',
#  '2019-01-09 07',
#  '2019-01-09 08',
#  '2019-01-09 09',
#  '2019-01-09 10',
#  '2019-01-09 11',
#  '2019-01-09 12',
#  '2019-01-09 13',
#  '2019-01-09 14',
#  '2019-01-09 15',
#  '2019-01-09 16',
#  '2019-01-09 17',
#  '2019-01-09 18',
#  '2019-01-09 19',
#  '2019-01-09 20',
#  '2019-01-09 21',
#  '2019-01-09 22',
#  '2019-01-09 23',
#  '2019-01-10 00',
#  '2019-01-10 01',
#  '2019-01-10 02',
#  '2019-01-10 03',
#  '2019-01-10 04',
#  '2019-01-10 05',
#  '2019-01-10 06',
#  '2019-01-10 07',
#  '2019-01-10 08',
#  '2019-01-10 09',
#  '2019-01-10 10',
#  '2019-01-10 11',
#  '2019-01-10 12',
#  '2019-01-10 13',
#  '2019-01-10 14',
#  '2019-01-10 15',
#  '2019-01-10 16',
#  '2019-01-10 17',
#  '2019-01-10 18',
#  '2019-01-10 19',
#  '2019-01-10 20',
#  '2019-01-10 21',
#  '2019-01-10 22',
#  '2019-01-10 23',
#  '2019-01-11 00',
#  '2019-01-11 01',
#  '2019-01-11 02',
#  '2019-01-11 03',
#  '2019-01-11 04',
#  '2019-01-11 05',
#  '2019-01-11 06',
#  '2019-01-11 07',
#  '2019-01-11 08',
#  '2019-01-11 09',
#  '2019-01-11 10',
#  '2019-01-11 11',
#  '2019-01-11 12',
#  '2019-01-11 13',
#  '2019-01-11 14',
#  '2019-01-11 15',
#  '2019-01-11 16',
#  '2019-01-11 17',
#  '2019-01-11 18',
#  '2019-01-11 19',
#  '2019-01-11 20',
#  '2019-01-11 21',
#  '2019-01-11 22',
#  '2019-01-11 23',
#  '2019-01-12 00',
#  '2019-01-12 01',
#  '2019-01-12 02',
#  '2019-01-12 03',
#  '2019-01-12 04',
#  '2019-01-12 05',
#  '2019-01-12 06',
#  '2019-01-12 07',
#  '2019-01-12 08',
#  '2019-01-12 09',
#  '2019-01-12 10',
#  '2019-01-12 11',
#  '2019-01-12 12',
#  '2019-01-12 13',
#  '2019-01-12 14',
#  '2019-01-12 15',
#  '2019-01-12 16',
#  '2019-01-12 17',
#  '2019-01-12 18',
#  '2019-01-12 19',
#  '2019-01-12 20',
#  '2019-01-12 21',
#  '2019-01-12 22',
#  '2019-01-12 23',
#  '2019-01-13 00',
#  '2019-01-13 01',
#  '2019-01-13 02',
#  '2019-01-13 03',
#  '2019-01-13 04',
#  '2019-01-13 05',
#  '2019-01-13 06',
#  '2019-01-13 07',
#  '2019-01-13 08',
#  '2019-01-13 09',
#  '2019-01-13 10',
#  '2019-01-13 11',
#  '2019-01-13 12',
#  '2019-01-13 13',
#  '2019-01-13 14',
#  '2019-01-13 15',
#  '2019-01-13 16',
#  '2019-01-13 17',
#  '2019-01-13 18',
#  '2019-01-13 19',
#  '2019-01-13 20',
#  '2019-01-13 21',
#  '2019-01-13 22',
#  '2019-01-13 23',
#  '2019-01-14 00',
#  '2019-01-14 01',
#  '2019-01-14 02',
#  '2019-01-14 03',
#  '2019-01-14 04',
#  '2019-01-14 05',
#  '2019-01-14 06',
#  '2019-01-14 07',
#  '2019-01-14 08',
#  '2019-01-14 09',
#  '2019-01-14 10',
#  '2019-01-14 11',
#  '2019-01-14 12',
#  '2019-01-14 13',
#  '2019-01-14 14',
#  '2019-01-14 15',
#  '2019-01-14 16',
#  '2019-01-14 17',
#  '2019-01-14 18',
#  '2019-01-14 19',
#  '2019-01-14 20',
#  '2019-01-14 21',
#  '2019-01-14 22',
#  '2019-01-14 23',
#  '2019-01-15 00',
#  '2019-01-15 01',
#  '2019-01-15 02',
#  '2019-01-15 03',
#  '2019-01-15 04',
#  '2019-01-15 05',
#  '2019-01-15 06',
#  '2019-01-15 07',
#  '2019-01-15 08',
#  '2019-01-15 09',
#  '2019-01-15 10',
#  '2019-01-15 11',
#  '2019-01-15 12',
#  '2019-01-15 13',
#  '2019-01-15 14',
#  '2019-01-15 15',
#  '2019-01-15 16',
#  '2019-01-15 17',
#  '2019-01-15 18',
#  '2019-01-15 19',
#  '2019-01-15 20',
#  '2019-01-15 21',
#  '2019-01-15 22',
#  '2019-01-15 23',
#  '2019-01-16 00',
#  '2019-01-16 01',
#  '2019-01-16 02',
#  '2019-01-16 03',
#  '2019-01-16 04',
#  '2019-01-16 05',
#  '2019-01-16 06',
#  '2019-01-16 07',
#  '2019-01-16 08',
#  '2019-01-16 09',
#  '2019-01-16 10',
#  '2019-01-16 11',
#  '2019-01-16 12',
#  '2019-01-16 13',
#  '2019-01-16 14',
#  '2019-01-16 15',
#  '2019-01-16 16',
#  '2019-01-16 17',
#  '2019-01-16 18',
#  '2019-01-16 19',
#  '2019-01-16 20',
#  '2019-01-16 21',
#  '2019-01-16 22',
#  '2019-01-16 23',
#  '2019-01-17 00',
#  '2019-01-17 01',
#  '2019-01-17 02',
#  '2019-01-17 03',
#  '2019-01-17 04',
#  '2019-01-17 05',
#  '2019-01-17 06',
#  '2019-01-17 07',
#  '2019-01-17 08',
#  '2019-01-17 09',
#  '2019-01-17 10',
#  '2019-01-17 11',
#  '2019-01-17 12',
#  '2019-01-17 13',
#  '2019-01-17 14',
#  '2019-01-17 15',
#  '2019-01-17 16',
#  '2019-01-17 17',
#  '2019-01-17 18',
#  '2019-01-17 19',
#  '2019-01-17 20',
#  '2019-01-17 21',
#  '2019-01-17 22',
#  '2019-01-17 23',
#  '2019-01-18 00',
#  '2019-01-18 01',
#  '2019-01-18 02',
#  '2019-01-18 03',
#  '2019-01-18 04',
#  '2019-01-18 05',
#  '2019-01-18 06',
#  '2019-01-18 07',
#  '2019-01-18 08',
#  '2019-01-18 09',
#  '2019-01-18 10',
#  '2019-01-18 11',
#  '2019-01-18 12',
#  '2019-01-18 13',
#  '2019-01-18 14',
#  '2019-01-18 15',
#  '2019-01-18 16',
#  '2019-01-18 17',
#  '2019-01-18 18',
#  '2019-01-18 19',
#  '2019-01-18 20',
#  '2019-01-18 21',
#  '2019-01-18 22',
#  '2019-01-18 23',
#  '2019-01-19 00',
#  '2019-01-19 01',
#  '2019-01-19 02',
#  '2019-01-19 03',
#  '2019-01-19 04',
#  '2019-01-19 05',
#  '2019-01-19 06',
#  '2019-01-19 07',
#  '2019-01-19 08',
#  '2019-01-19 09',
#  '2019-01-19 10',
#  '2019-01-19 11',
#  '2019-01-19 12',
#  '2019-01-19 13',
#  '2019-01-19 14',
#  '2019-01-19 15',
#  '2019-01-19 16',
#  '2019-01-19 17',
#  '2019-01-19 18',
#  '2019-01-19 19',
#  '2019-01-19 20',
#  '2019-01-19 21',
#  '2019-01-19 22',
#  '2019-01-19 23',
#  '2019-01-20 00',
#  '2019-01-20 01',
#  '2019-01-20 02',
#  '2019-01-20 03',
#  '2019-01-20 04',
#  '2019-01-20 05',
#  '2019-01-20 06',
#  '2019-01-20 07',
#  '2019-01-20 08',
#  '2019-01-20 09',
#  '2019-01-20 10',
#  '2019-01-20 11',
#  '2019-01-20 12',
#  '2019-01-20 13',
#  '2019-01-20 14',
#  '2019-01-20 15',
#  '2019-01-20 16',
#  '2019-01-20 17',
#  '2019-01-20 18',
#  '2019-01-20 19',
#  '2019-01-20 20',
#  '2019-01-20 21',
#  '2019-01-20 22',
#  '2019-01-20 23',
#  '2019-01-21 00',
#  '2019-01-21 01',
#  '2019-01-21 02',
#  '2019-01-21 03',
#  '2019-01-21 04',
#  '2019-01-21 05',
#  '2019-01-21 06',
#  '2019-01-21 07',
#  '2019-01-21 08',
#  '2019-01-21 09',
#  '2019-01-21 10',
#  '2019-01-21 11',
#  '2019-01-21 12',
#  '2019-01-21 13',
#  '2019-01-21 14',
#  '2019-01-21 15',
#  '2019-01-21 16',
#  '2019-01-21 17',
#  '2019-01-21 18',
#  '2019-01-21 19',
#  '2019-01-21 20',
#  '2019-01-21 21',
#  '2019-01-21 22',
#  '2019-01-21 23',
#  '2019-01-22 00',
#  '2019-01-22 01',
#  '2019-01-22 02',
#  '2019-01-22 03',
#  '2019-01-22 04',
#  '2019-01-22 05',
#  '2019-01-22 06',
#  '2019-01-22 07',
#  '2019-01-22 08',
#  '2019-01-22 09',
#  '2019-01-22 10',
#  '2019-01-22 11',
#  '2019-01-22 12',
#  '2019-01-22 13',
#  '2019-01-22 14',
#  '2019-01-22 15',
#  '2019-01-22 16',
#  '2019-01-22 17',
#  '2019-01-22 18',
#  '2019-01-22 19',
#  '2019-01-22 20',
#  '2019-01-22 21',
#  '2019-01-22 22',
#  '2019-01-22 23',
#  '2019-01-23 00',
#  '2019-01-23 01',
#  '2019-01-23 02',
#  '2019-01-23 03',
#  '2019-01-23 04',
#  '2019-01-23 05',
#  '2019-01-23 06',
#  '2019-01-23 07',
#  '2019-01-23 08',
#  '2019-01-23 09',
#  '2019-01-23 10',
#  '2019-01-23 11',
#  '2019-01-23 12',
#  '2019-01-23 13',
#  '2019-01-23 14',
#  '2019-01-23 15',
#  '2019-01-23 16',
#  '2019-01-23 17',
#  '2019-01-23 18',
#  '2019-01-23 19',
#  '2019-01-23 20',
#  '2019-01-23 21',
#  '2019-01-23 22',
#  '2019-01-23 23',
#  '2019-01-24 00',
#  '2019-01-24 01',
#  '2019-01-24 02',
#  '2019-01-24 03',
#  '2019-01-24 04',
#  '2019-01-24 05',
#  '2019-01-24 06',
#  '2019-01-24 07',
#  '2019-01-24 08',
#  '2019-01-24 09',
#  '2019-01-24 10',
#  '2019-01-24 11',
#  '2019-01-24 12',
#  '2019-01-24 13',
#  '2019-01-24 14',
#  '2019-01-24 15',
#  '2019-01-24 16',
#  '2019-01-24 17',
#  '2019-01-24 18',
#  '2019-01-24 19',
#  '2019-01-24 20',
#  '2019-01-24 21',
#  '2019-01-24 22',
#  '2019-01-24 23',
#  '2019-01-25 00',
#  '2019-01-25 01',
#  '2019-01-25 02',
#  '2019-01-25 03',
#  '2019-01-25 04',
#  '2019-01-25 05',
#  '2019-01-25 06',
#  '2019-01-25 07',
#  '2019-01-25 08',
#  '2019-01-25 09',
#  '2019-01-25 10',
#  '2019-01-25 11',
#  '2019-01-25 12',
#  '2019-01-25 13',
#  '2019-01-25 14',
#  '2019-01-25 15',
#  '2019-01-25 16',
#  '2019-01-25 17',
#  '2019-01-25 18',
#  '2019-01-25 19',
#  '2019-01-25 20',
#  '2019-01-25 21',
#  '2019-01-25 22',
#  '2019-01-25 23',
#  '2019-01-26 00',
#  '2019-01-26 01',
#  '2019-01-26 02',
#  '2019-01-26 03',
#  '2019-01-26 04',
#  '2019-01-26 05',
#  '2019-01-26 06',
#  '2019-01-26 07',
#  '2019-01-26 08',
#  '2019-01-26 09',
#  '2019-01-26 10',
#  '2019-01-26 11',
#  '2019-01-26 12',
#  '2019-01-26 13',
#  '2019-01-26 14',
#  '2019-01-26 15',
#  '2019-01-26 16',
#  '2019-01-26 17',
#  '2019-01-26 18',
#  '2019-01-26 19',
#  '2019-01-26 20',
#  '2019-01-26 21',
#  '2019-01-26 22',
#  '2019-01-26 23',
#  '2019-01-27 00',
#  '2019-01-27 01',
#  '2019-01-27 02',
#  '2019-01-27 03',
#  '2019-01-27 04',
#  '2019-01-27 05',
#  '2019-01-27 06',
#  '2019-01-27 07',
#  '2019-01-27 08',
#  '2019-01-27 09',
#  '2019-01-27 10',
#  '2019-01-27 11',
#  '2019-01-27 12',
#  '2019-01-27 13',
#  '2019-01-27 14',
#  '2019-01-27 15',
#  '2019-01-27 16',
#  '2019-01-27 17',
#  '2019-01-27 18',
#  '2019-01-27 19',
#  '2019-01-27 20',
#  '2019-01-27 21',
#  '2019-01-27 22',
#  '2019-01-27 23',
#  '2019-01-28 00',
#  '2019-01-28 01',
#  '2019-01-28 02',
#  '2019-01-28 03',
#  '2019-01-28 04',
#  '2019-01-28 05',
#  '2019-01-28 06',
#  '2019-01-28 07',
#  '2019-01-28 08',
#  '2019-01-28 09',
#  '2019-01-28 10',
#  '2019-01-28 11',
#  '2019-01-28 12',
#  '2019-01-28 13',
#  '2019-01-28 14',
#  '2019-01-28 15',
#  '2019-01-28 16',
#  '2019-01-28 17',
#  '2019-01-28 18',
#  '2019-01-28 19',
#  '2019-01-28 20',
#  '2019-01-28 21',
#  '2019-01-28 22',
#  '2019-01-28 23',
#  '2019-01-29 00',
#  '2019-01-29 01',
#  '2019-01-29 02',
#  '2019-01-29 03',
#  '2019-01-29 04',
#  '2019-01-29 05',
#  '2019-01-29 06',
#  '2019-01-29 07',
#  '2019-01-29 08',
#  '2019-01-29 09',
#  '2019-01-29 10',
#  '2019-01-29 11',
#  '2019-01-29 12',
#  '2019-01-29 13',
#  '2019-01-29 14',
#  '2019-01-29 15',
#  '2019-01-29 16',
#  '2019-01-29 17',
#  '2019-01-29 18',
#  '2019-01-29 19',
#  '2019-01-29 20',
#  '2019-01-29 21',
#  '2019-01-29 22',
#  '2019-01-29 23',
#  '2019-01-30 00',
#  '2019-01-30 01',
#  '2019-01-30 02',
#  '2019-01-30 03',
#  '2019-01-30 04',
#  '2019-01-30 05',
#  '2019-01-30 06',
#  '2019-01-30 07',
#  '2019-01-30 08',
#  '2019-01-30 09',
#  '2019-01-30 10',
#  '2019-01-30 11',
#  '2019-01-30 12',
#  '2019-01-30 13',
#  '2019-01-30 14',
#  '2019-01-30 15',
#  '2019-01-30 16',
#  '2019-01-30 17',
#  '2019-01-30 18',
#  '2019-01-30 19',
#  '2019-01-30 20',
#  '2019-01-30 21',
#  '2019-01-30 22',
#  '2019-01-30 23',
#  '2019-01-31 00',
#  '2019-01-31 01',
#  '2019-01-31 02',
#  '2019-01-31 03',
#  '2019-01-31 04',
#  '2019-01-31 05',
#  '2019-01-31 06',
#  '2019-01-31 07',
#  '2019-01-31 08',
#  '2019-01-31 09',
#  '2019-01-31 10',
#  '2019-01-31 11',
#  '2019-01-31 12',
#  '2019-01-31 13',
#  '2019-01-31 14',
#  '2019-01-31 15',
#  '2019-01-31 16',
#  '2019-01-31 17',
#  '2019-01-31 18',
#  '2019-01-31 19',
#  '2019-01-31 20',
#  '2019-01-31 21',
#  '2019-01-31 22',
#  '2019-01-31 23',
#  '2019-02-01 00',
#  '2019-02-01 01',
#  '2019-02-01 02',
#  '2019-02-01 03',
#  '2019-02-01 04',
#  '2019-02-01 05',
#  '2019-02-01 06',
#  '2019-02-01 07',
#  '2019-02-01 08',
#  '2019-02-01 09',
#  '2019-02-01 10',
#  '2019-02-01 11',
#  '2019-02-01 12',
#  '2019-02-01 13',
#  '2019-02-01 14',
#  '2019-02-01 15',
#  '2019-02-01 16',
#  '2019-02-01 17',
#  '2019-02-01 18',
#  '2019-02-01 19',
#  '2019-02-01 20',
#  '2019-02-01 21',
#  '2019-02-01 22',
#  '2019-02-01 23',
#  '2019-02-02 00',
#  '2019-02-02 01',
#  '2019-02-02 02',
#  '2019-02-02 03',
#  '2019-02-02 04',
#  '2019-02-02 05',
#  '2019-02-02 06',
#  '2019-02-02 07',
#  '2019-02-02 08',
#  '2019-02-02 09',
#  '2019-02-02 10',
#  '2019-02-02 11',
#  '2019-02-02 12',
#  '2019-02-02 13',
#  '2019-02-02 14',
#  '2019-02-02 15',
#  '2019-02-02 16',
#  '2019-02-02 17',
#  '2019-02-02 18',
#  '2019-02-02 19',
#  '2019-02-02 20',
#  '2019-02-02 21',
#  '2019-02-02 22',
#  '2019-02-02 23',
#  '2019-02-03 00',
#  '2019-02-03 01',
#  '2019-02-03 02',
#  '2019-02-03 03',
#  '2019-02-03 04',
#  '2019-02-03 05',
#  '2019-02-03 06',
#  '2019-02-03 07',
#  '2019-02-03 08',
#  '2019-02-03 09',
#  '2019-02-03 10',
#  '2019-02-03 11',
#  '2019-02-03 12',
#  '2019-02-03 13',
#  '2019-02-03 14',
#  '2019-02-03 15',
#  '2019-02-03 16',
#  '2019-02-03 17',
#  '2019-02-03 18',
#  '2019-02-03 19',
#  '2019-02-03 20',
#  '2019-02-03 21',
#  '2019-02-03 22',
#  '2019-02-03 23',
#  '2019-02-04 00',
#  '2019-02-04 01',
#  '2019-02-04 02',
#  '2019-02-04 03',
#  '2019-02-04 04',
#  '2019-02-04 05',
#  '2019-02-04 06',
#  '2019-02-04 07',
#  '2019-02-04 08',
#  '2019-02-04 09',
#  '2019-02-04 10',
#  '2019-02-04 11',
#  '2019-02-04 12',
#  '2019-02-04 13',
#  '2019-02-04 14',
#  '2019-02-04 15',
#  '2019-02-04 16',
#  '2019-02-04 17',
#  '2019-02-04 18',
#  '2019-02-04 19',
#  '2019-02-04 20',
#  '2019-02-04 21',
#  '2019-02-04 22',
#  '2019-02-04 23',
#  '2019-02-05 00',
#  '2019-02-05 01',
#  '2019-02-05 02',
#  '2019-02-05 03',
#  '2019-02-05 04',
#  '2019-02-05 05',
#  '2019-02-05 06',
#  '2019-02-05 07',
#  '2019-02-05 08',
#  '2019-02-05 09',
#  '2019-02-05 10',
#  '2019-02-05 11',
#  '2019-02-05 12',
#  '2019-02-05 13',
#  '2019-02-05 14',
#  '2019-02-05 15',
#  '2019-02-05 16',
#  '2019-02-05 17',
#  '2019-02-05 18',
#  '2019-02-05 19',
#  '2019-02-05 20',
#  '2019-02-05 21',
#  '2019-02-05 22',
#  '2019-02-05 23',
#  '2019-02-06 00',
#  '2019-02-06 01',
#  '2019-02-06 02',
#  '2019-02-06 03',
#  '2019-02-06 04',
#  '2019-02-06 05',
#  '2019-02-06 06',
#  '2019-02-06 07',
#  '2019-02-06 08',
#  '2019-02-06 09',
#  '2019-02-06 10',
#  '2019-02-06 11',
#  '2019-02-06 12',
#  '2019-02-06 13',
#  '2019-02-06 14',
#  '2019-02-06 15',
#  '2019-02-06 16',
#  '2019-02-06 17',
#  '2019-02-06 18',
#  '2019-02-06 19',
#  '2019-02-06 20',
#  '2019-02-06 21',
#  '2019-02-06 22',
#  '2019-02-06 23',
#  '2019-02-07 00',
#  '2019-02-07 01',
#  '2019-02-07 02',
#  '2019-02-07 03',
#  '2019-02-07 04',
#  '2019-02-07 05',
#  '2019-02-07 06',
#  '2019-02-07 07',
#  '2019-02-07 08',
#  '2019-02-07 09',
#  '2019-02-07 10',
#  '2019-02-07 11',
#  '2019-02-07 12',
#  '2019-02-07 13',
#  '2019-02-07 14',
#  '2019-02-07 15',
#  '2019-02-07 16',
#  '2019-02-07 17',
#  '2019-02-07 18',
#  '2019-02-07 19',
#  '2019-02-07 20',
#  '2019-02-07 21',
#  '2019-02-07 22',
#  '2019-02-07 23',
#  '2019-02-08 00',
#  '2019-02-08 01',
#  '2019-02-08 02',
#  '2019-02-08 03',
#  '2019-02-08 04',
#  '2019-02-08 05',
#  '2019-02-08 06',
#  '2019-02-08 07',
#  '2019-02-08 08',
#  '2019-02-08 09',
#  '2019-02-08 10',
#  '2019-02-08 11',
#  '2019-02-08 12',
#  '2019-02-08 13',
#  '2019-02-08 14',
#  '2019-02-08 15',
#  '2019-02-08 16',
#  '2019-02-08 17',
#  '2019-02-08 18',
#  '2019-02-08 19',
#  '2019-02-08 20',
#  '2019-02-08 21',
#  '2019-02-08 22',
#  '2019-02-08 23',
#  '2019-02-09 00',
#  '2019-02-09 01',
#  '2019-02-09 02',
#  '2019-02-09 03',
#  '2019-02-09 04',
#  '2019-02-09 05',
#  '2019-02-09 06',
#  '2019-02-09 07',
#  '2019-02-09 08',
#  '2019-02-09 09',
#  '2019-02-09 10',
#  '2019-02-09 11',
#  '2019-02-09 12',
#  '2019-02-09 13',
#  '2019-02-09 14',
#  '2019-02-09 15',
#  '2019-02-09 16',
#  '2019-02-09 17',
#  '2019-02-09 18',
#  '2019-02-09 19',
#  '2019-02-09 20',
#  '2019-02-09 21',
#  '2019-02-09 22',
#  '2019-02-09 23',
#  '2019-02-10 00',
#  '2019-02-10 01',
#  '2019-02-10 02',
#  '2019-02-10 03',
#  '2019-02-10 04',
#  '2019-02-10 05',
#  '2019-02-10 06',
#  '2019-02-10 07',
#  '2019-02-10 08',
#  '2019-02-10 09',
#  '2019-02-10 10',
#  '2019-02-10 11',
#  '2019-02-10 12',
#  '2019-02-10 13',
#  '2019-02-10 14',
#  '2019-02-10 15',
#  '2019-02-10 16',
#  '2019-02-10 17',
#  '2019-02-10 18',
#  '2019-02-10 19',
#  '2019-02-10 20',
#  '2019-02-10 21',
#  '2019-02-10 22',
#  '2019-02-10 23',
#  '2019-02-11 00',
#  '2019-02-11 01',
#  '2019-02-11 02',
#  '2019-02-11 03',
#  '2019-02-11 04',
#  '2019-02-11 05',
#  '2019-02-11 06',
#  '2019-02-11 07',
#  '2019-02-11 08',
#  '2019-02-11 09',
#  '2019-02-11 10',
#  '2019-02-11 11',
#  '2019-02-11 12',
#  '2019-02-11 13',
#  '2019-02-11 14',
#  '2019-02-11 15',
#  ...]

# %%
forecast_df.dtypes
# Out:
# CODE           object
# STATUS         object
# FCDATE         object
# LOCATION       object
# FCDATETIME     object
# FCYYYY          int64
# FCMM            int64
# FCDD            int64
# FCHH            int64
# FCDOWNUM        int64
# FCDOWTEXT      object
# TMP             int64
# DPT             int64
# HUM             int64
# CC              int64
# CREATEDBY      object
# CREATEDDATE    object
# dtype: object
